# %%
# Here I'm importing all the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the dataset
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# data preprocessing

# %%
data['Height'] = np.random.randint(150, 181, size=len(data))

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2   John Holland  Boston Celtics      30       SG   27     156     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     174     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Fill missing values in the "salary" column with the mean value
mean_salary = data['Salary'].mean()
data['Salary'].fillna(mean_salary, inplace=True)

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2   John Holland  Boston Celtics      30       SG   27     156     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     174     231
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.833970e+06
# 3      Georgia State  1.148640e+06
# 4                NaN  5.000000e+06

# %%
# Fill missing values in the "college" column with the mode value
mode_college = data['College'].mode().iloc[0]
data['College'].fillna(mode_college, inplace=True)

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2   John Holland  Boston Celtics      30       SG   27     156     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     174     231
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.833970e+06
# 3      Georgia State  1.148640e+06
# 4           Kentucky  5.000000e+06

# %%
# Droping unwanted columns
data = data.drop('Number', axis=1)

# %%
data
# Out:
#               Name            Team Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       PG   25     155     180
# 1      Jae Crowder  Boston Celtics       SF   25     177     235
# 2     John Holland  Boston Celtics       SG   27     156     205
# 3      R.J. Hunter  Boston Celtics       SG   22     175     185
# 4    Jonas Jerebko  Boston Celtics       PF   29     174     231
# ..             ...             ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       PG   26     154     203
# 454      Raul Neto       Utah Jazz       PG   24     158     179
# 455   Tibor Pleiss       Utah Jazz        C   26     165     256
# 456    Jeff Withey       Utah Jazz        C   26     180     231
# 457       Priyanka       Utah Jazz        C   25     163     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# 1            Marquette  6.796117e+06
# 2    Boston University  4.833970e+06
# ...

# %% [markdown]
# #### How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
# Count employees in each team
team_counts = data['Team'].value_counts()

# Calculate percentage splitting
total_employees = len(data)
team_percentages = (team_counts / total_employees) * 100

# Display team counts and percentages
print("Team Counts:")
print(team_counts)
print("Team Percentages:")
print(team_percentages)
# Out:
# Team Counts:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64
# Team Percentages:
# ...

# %% [markdown]
# #### Segregate the employees with respect to different positions.

# %%
# Segregate employees by position
position_counts = data.groupby('Position').size()

# Display position counts
print("Position Counts:")
print(position_counts)
# Out:
# Position Counts:
# Position
# C      79
# PF    100
# PG     92
# SF     85
# SG    102
# dtype: int64

# %%
dataset = data

# %% [markdown]
# #### Find from which age group most of the employees belong to.

# %%
# Categorize age into groups
age_groups = pd.cut(data['Age'], bins=[20, 30, 40, 50, 60, 70])

# Find the most common age group
most_common_age_group = age_groups.value_counts().idxmax()

# Display the most common age group
print("Most Common Age Group:")
print(most_common_age_group)
# Out:
# Most Common Age Group:
# (20, 30]

# %% [markdown]
# #### Find out under which team and position, spending in terms of salary is high.

# %%
# Calculate total salary spending for each team and position
salary_spending = data.groupby(['Team', 'Position'])['Salary'].sum()

# Find the team and position with high salary spending
high_salary = salary_spending.idxmax()

# Display the team and position with high salary spending
print("Team and Position with High Salary Spending:")
print(high_salary)
# Out:
# Team and Position with High Salary Spending:
# ('Los Angeles Lakers', 'SF')

# %% [markdown]
# #### Find if there is any correlation between age and salary , represent it visually.

# %%
# Calculating the correlation between age and salary
correlation = data['Age'].corr(dataset['Salary'])

# Creating a scatter plot of age vs salary
plt.scatter(dataset['Age'], dataset['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation between Age and Salary')
plt.show()

# Display the correlation coefficient
print("Correlation Coefficient:")
print(correlation)
# Out:
# Correlation Coefficient:
# 0.21116954917686373

# %%
correlation = data['Age'].corr(data['Salary'])

# %%
correlation
# Out:
# 0.21116954917686373
